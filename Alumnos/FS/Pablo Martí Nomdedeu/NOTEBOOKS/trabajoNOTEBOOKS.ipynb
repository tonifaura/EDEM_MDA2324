# %% [markdown]
# HIPOTESIS: La socidad española individualmente es crítica y no solo somos espectadores de películas de humor.

# %% [markdown]
# A continuación, vamos hacer un análisis a traves de gráficas para asegurar que las hipotesis que hemos establecido son las correctas, es decir, los españoles individualmente cuando vemos una película, tenemos un buen caracter crítico y no somos un país de peliculas de humor y sin mucho argumento

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

file_path = "/Users/pablomartinomdedeu/Documents/GitHub/EDEM_MDA2324/Alumnos/FS/Pablo Martí Nomdedeu/NOTEBOOKS/reviews_filmaffinity.csv"

try:
    # Intenta cargar el archivo CSV
    df = pd.read_csv(file_path, delimiter=',', header=0, encoding='utf-8', on_bad_lines='skip')
    print(df)
except pd.errors.ParserError as e:
    # Manejar el error de lectura del archivo CSV
    print(f"Error al leer el archivo CSV: {e}")
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
