# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import statistics
import scipy.stats
from distfit import distfit

# %%
df = pd.read_csv('C:\\Users\\josan\\Documents\\GitHub\\EDEM_MDA2324\\Alumnos\\ES\\Josan_Rodrigo_Cortes\\Estadística\\features_v1.unknown',delimiter=',')
df.head(10)
# Out:
#    Unnamed: 0  Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  SCC  \
# 0           0       0                               1     0     2      0    0
# 1           1       0                               1     0     2      1    1
# 2           2       1                               1     0     2      0    0
# 3           3       1                               0     0     2      0    0
# 4           4       1                               0     0     2      0    0
# 5           5       1                               0     1     2      0    0
# 6           6       0                               1     1     2      0    0
# 7           7       1                               0     0     2      0    0
# 8           8       1                               1     1     2      0    0
# 9           9       1                               1     1     2      0    0
#
#    CALC  MTRANS       Age    Height    Weight  FCVC       NCP  CH2O       FAF  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0        Gender  family_history_with_overweight  \
# count  22869.000000  22869.000000                    22869.000000
# mean   11434.000000      0.498666                        0.819450
# std     6601.855989      0.500009                        0.384653
# min        0.000000      0.000000                        0.000000
# 25%     5717.000000      0.000000                        1.000000
# 50%    11434.000000      0.000000                        1.000000
# 75%    17151.000000      1.000000                        1.000000
# max    22868.000000      1.000000                        1.000000
#
#                FAVC          CAEC         SMOKE           SCC          CALC  \
# count  22869.000000  22869.000000  22869.000000  22869.000000  22869.000000
# mean       0.911627      1.849316      0.012637      0.034238      2.227426
# std        0.283843      0.450872      0.111705      0.181845      0.477871
# ...

# %%
df.boxplot(column='BMI')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Unnamed: 0'], df['BMI'])
plt.xlabel('Valores de Unnamed')
plt.ylabel('Valores de BMI')
plt.title('Gráfico de dispersión entre Unnamed y BMI')
plt.show()

# %%
df["BMI"].plot(kind="density",  # Create density plot
                      figsize=(8,8),    # Set figure size
                      xlim= (12))
# Out:
# <Axes: ylabel='Density'>

# %%
df['BMI'].hist(range=(12,55),bins=11)
# Out:
# <Axes: >

# %%
df_1=df[df['Gender']==1]
df_1.head(3)
df_1.describe()
df_1['BMI'].hist(range=(12,55),bins=11)
# Out:
# <Axes: >

# %%
df_0=df[df['Gender']==0]
df_0.head(3)
df_0['BMI'].hist(range=(12,55),bins=11)
# Out:
# <Axes: >

# %%
# Initialize distfit
dist = distfit()

# Fit the distribution to your BMI data
dist.fit_transform(df['BMI'])

# Print the summary of the best fit distribution
print(dist.summary)

# Optionally, you can also plot the best fit distribution against your data
dist.plot()
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.0 sec] [RSS: 0.00795911] [loc=30.192 scale=8.306]
# [distfit] >INFO> [expon     ] [0.0 sec] [RSS: 0.0210251] [loc=12.869 scale=17.323]
# [distfit] >INFO> [pareto    ] [0.03 sec] [RSS: 0.0210251] [loc=-2147483635.131 scale=2147483648.000]
# [distfit] >INFO> [dweibull  ] [0.27 sec] [RSS: 0.00724786] [loc=30.242 scale=7.896]
# [distfit] >INFO> [t         ] [1.91 sec] [RSS: 0.00796184] [loc=30.194 scale=8.304]
# [distfit] >INFO> [genextreme] [0.72 sec] [RSS: 0.00758382] [loc=27.274 scale=8.168]
# [distfit] >INFO> [gamma     ] [0.55 sec] [RSS: 0.00792776] [loc=-177.600 scale=0.332]
# [distfit] >INFO> [lognorm   ] [0.00 sec] [RSS: 0.00791279] [loc=-110.368 scale=140.314]
# [distfit] >INFO> [beta      ] [1.42 sec] [RSS: 0.00656109] [loc=12.655 scale=42.433]
# [distfit] >INFO> [uniform   ] [0.0 sec] [RSS: 0.0156162] [loc=12.869 scale=42.129]
# ...
