# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

# %%
billns = pd.read_csv('sample_data/Billionaires Statistic.csv')
billns.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
billns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rank                                        2640 non-null   int64
#  1   finalWorth                                  2640 non-null   int64
#  2   category                                    2640 non-null   object
#  3   personName                                  2640 non-null   object
#  4   age                                         2575 non-null   float64
#  5   country                                     2602 non-null   object
#  6   city                                        2568 non-null   object
#  7   source                                      2640 non-null   object
#  8   industries                                  2640 non-null   object
#  9   countryOfCitizenship                        2640 non-null   object
# ...

# %%
bill2 = billns.groupby('personName')['finalWorth'].sum().sort_values(ascending=False)

richest_p = bill2.head(10)

plt.figure(figsize=(12, 8))
richest_p.plot(kind='bar', color='gold')
plt.title('Top 10 $$$')
plt.xlabel('Who?')
plt.ylabel('How much??')
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# #**Breve presentación de cada persona del top 10 e industria a la que se dedica:**
#
# 1.   ***Bernard Arnault:*** Es un empresario francés y presidente del grupo de lujo LVMH (Moët, Hennessy,Louis Vuitton), que abarca diversas marcas de moda, joyería, perfumes y otros bienes de lujo.
#
# 2.   ***Elon Musk:*** Es un empresario y emprendedor sudafricano-estadounidense conocido por ser el CEO de Tesla, una empresa de vehículos eléctricos y energía renovable, y SpaceX, una compañía aeroespacial.
#
# 3.   ***Jeff Bezos:*** Fundador de Amazon, una de las mayores empresas de comercio electrónico y servicios en la nube del mundo.
#
# 4.   ***Larry Ellison:*** Es el fundador y director ejecutivo de Oracle Corporation, una empresa líder en el desarrollo y comercialización de software y hardware para sistemas de gestión de bases de datos.
#
# 5.   ***Warren Buffett:*** Es un inversor y empresario estadounidense, conocido como uno de los inversores más exitosos de todos los tiempos. Es el presidente y CEO de Berkshire Hathaway, una empresa holding con inversiones en diversas industrias.
#
# 6.   ***Bill Gates:*** Cofundador de Microsoft, una de las mayores empresas de tecnología del mundo, conocida por su software, sistemas operativos y productos informáticos.
#
# 7.   ***Michael Bloomberg:*** Empresario y político estadounidense, fundador de Bloomberg L.P., una empresa de servicios financieros, datos y medios de comunicación.
#
# 8.   ***Carlos Slim Helú:*** Empresario mexicano, magnate de las telecomunicaciones. Controla Grupo Carso, que incluye empresas en sectores como telecomunicaciones, construcción, y comercio minorista.
#
# 9.   ***Mukesh Ambani:*** Es el presidente de Reliance Industries, una conglomerada india con intereses en petroquímicos, refinerías, telecomunicaciones, y
# comercio minorista, entre otros.
#
# 10.  ***Steve Ballmer:*** Ex CEO de Microsoft, también es conocido por ser propietario del equipo de baloncesto Los Angeles Clippers. Durante su tiempo en Microsoft, la compañía se destacó en software, sistemas operativos y productos informáticos.

# %%
# Histogram of the age distribution of billionaires
sns.histplot(
    x='age',
    data=billns,
)
plt.xlabel('Age')
plt.ylabel('Number of Billionaires')
plt.title('Age Distribution of Billionaires')
plt.show()

# %% [markdown]
# Por lo que parece, si te haces Billonario, sera a partir de los 4*

# %%
fig = px.pie(billns.head(100), values='finalWorth', names='country', title='TOp-100 Billionaires by Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title USA SIEMPRE GANA
# %%html
<iframe width="560" height="315" src="https://www.youtube.com/embed/EwLWNXFH2rg?si=WU_wrPjq1yTa2XGp" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/EwLWNXFH2rg?si=WU_wrPjq1yTa2XGp" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %%
gender_counts = billns['gender'].value_counts()

fig3 = px.pie(gender_counts, labels=gender_counts.index, values=gender_counts.values,
              title="Gender Distribution of Billionaires",
              color_discrete_sequence=px.colors.qualitative.Plotly)
fig3.update_traces(marker=dict(line=dict(color='white', width=2)))
fig3.update_layout(showlegend=False)
fig3.update_traces(hole=0.4)

gender_labels = gender_counts.index
fig3.add_annotation(
    text="<b>Gender</b>",
    x=0.5,
    y=0.5,
    showarrow=False,
    font=dict(size=15),
)
fig3.add_annotation(
    text=gender_labels[0],
    x=0.53,
    y=0.1,
    showarrow=False,
    font=dict(size=12),
)
fig3.add_annotation(
    text=gender_labels[1],
    x=0.47,
    y=0.81,
    showarrow=False,
    font=dict(size=12),
)

fig3.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Como podemos ver en la distribución por genero, la igualdad todavia no ha alcanzado a los billonarios.
